# %%
class Person:
    def __init__(self, name):
        self.name = name
        print(f"Person created with name: {self.name}")

class Teacher(Person):
    def __init__(self, name, subject):
        super().__init__(name)  # Call base class constructor
        self.subject = subject
        print(f"Teacher created with subject: {self.subject}")

# Example usage
t = Teacher("Mr. Faizan", "Mathematics")
# Out:
# Person created with name: Mr. Faizan
# Teacher created with subject: Mathematics
