# %%
def main():
    # Loop from 0 to 19 (inclusive), and print i * 2 to get even numbers
    for i in range(20):
        print(i * 2)

# This line calls main() when the script is executed
if __name__ == '__main__':
    main()
