# %%
class Logger:
    def __init__(self):
        print("Logger object has been created.")

    def __del__(self):
        print("Logger object is being destroyed.")

# Example usage:
logger = Logger()

# To trigger destruction manually (optional, for demonstration)
del logger
# Out:
# Logger object has been created.
# Logger object is being destroyed.
