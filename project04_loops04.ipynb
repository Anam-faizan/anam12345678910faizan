# %%
def main():
    # Countdown from 10 to 1
    for i in range(10, 0, -1):
        print(i)

    # Output "Liftoff!" after the countdown
    print("Liftoff!")

# This line ensures that the main() function is called when the script runs
if __name__ == '__main__':
    main()
