# %%
def get_name():
    return "Sophia"

# There is no need to edit code beyond this point
def main():
    name = get_name()  # get_name() returns the name string
    print("Howdy", name, "! 🤠")

if __name__ == '__main__':
    main()
