# %%
def main():
    animal = input("What's your favorite animal? ")
    print("My favorite animal is also " + animal + "!")

# Required line to call main function when script is run directly
if __name__ == '__main__':
    main()
